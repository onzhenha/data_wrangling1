# %% [markdown]
# # Dependencies

# %%
import pandas as pd

# %% [markdown]
# ### We can read CSV files using pandas but we are going to create
# ### For reading CSV files using pandas, you can write this code --> `pd.read_csv("xxxxxxx.csv")`

# %% [markdown]
# #### Here is how we create a dataframe using pandas

# %%
data = {
    "order_id": [1, 2, 3, 4, 5, 6, 7],
    "customer_id": ["C001", "C002", "C001", "C003", "C004", "C002", "C005"],
    "country": ["SG", "MY", "SG", "TH", "SG", "MY", "PH"],
    "product": [
        "Ink Tank Printer",
        "Mono Laser",
        "Ink Bottle",
        "Colour Laser",
        "Toner",
        "Ink Bottle",
        "Ink Tank Printer"
    ],
    "category": [
        "Printer",
        "Printer",
        "Consumable",
        "Printer",
        "Consumable",
        "Consumable",
        "Printer"
    ],
    "price": [299, 199, 15, None, 120, 15, 289],
    "quantity": [1, 2, 3, 1, None, 5, 1],
    "order_date": [
        "2025-01-01 10:05",
        "2025-01-01 11:10",
        "2025-01-02 09:30",
        "2025-01-02 14:00",
        "2025-01-03 16:45",
        "2025-01-03 17:10",
        "2025-01-04 10:00"
    ],
    "email": [
        "USER1@EMAIL.COM",
        "user2@email.com",
        "user1@email.com",
        "user3@email.com",
        "user4@email.com",
        "user2@email.com",
        "user5@email.com"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 3         4        C003      TH      Colour Laser     Printer    NaN
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity        order_date            email
# 0       1.0  2025-01-01 10:05  USER1@EMAIL.COM
# 1       2.0  2025-01-01 11:10  user2@email.com
# 2       3.0  2025-01-02 09:30  user1@email.com
# 3       1.0  2025-01-02 14:00  user3@email.com
# 4       NaN  2025-01-03 16:45  user4@email.com
# 5       5.0  2025-01-03 17:10  user2@email.com
# 6       1.0  2025-01-04 10:00  user5@email.com

# %% [markdown]
# ### Calling the unique values of each columns

# %%
df["price"].unique()
# Out:
# array([299., 199.,  15.,  nan, 120., 289.])

# %%
df["quantity"].unique()
# Out:
# array([ 1.,  2.,  3., nan,  5.])

# %%
df["order_date"].unique()
# Out:
# array(['2025-01-01 10:05', '2025-01-01 11:10', '2025-01-02 09:30',
#        '2025-01-02 14:00', '2025-01-03 16:45', '2025-01-03 17:10',
#        '2025-01-04 10:00'], dtype=object)

# %% [markdown]
# ### Select the columns we want and have it in dataframe format

# %%
df_select =\
(
    df[["customer_id", "country", "product", "price"]]
)

df_select
# Out:
#   customer_id country           product  price
# 0        C001      SG  Ink Tank Printer  299.0
# 1        C002      MY        Mono Laser  199.0
# 2        C001      SG        Ink Bottle   15.0
# 3        C003      TH      Colour Laser    NaN
# 4        C004      SG             Toner  120.0
# 5        C002      MY        Ink Bottle   15.0
# 6        C005      PH  Ink Tank Printer  289.0

# %%
df["price"]
df[["price"]]
# Out:
#    price
# 0  299.0
# 1  199.0
# 2   15.0
# 3    NaN
# 4  120.0
# 5   15.0
# 6  289.0

# %% [markdown]
# ### Filtering out the rows that we want with specific filters

# %% [markdown]
# #### .query method

# %%
df_sg=\
(
    df
    .query("country == 'SG'")
)

df_sg
# Out:
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
#
#    quantity        order_date            email
# 0       1.0  2025-01-01 10:05  USER1@EMAIL.COM
# 2       3.0  2025-01-02 09:30  user1@email.com
# 4       NaN  2025-01-03 16:45  user4@email.com

# %%
df_sg_printer=\
(
    df
    .query("country == 'SG' & category == 'Printer'")
)
df_sg_printer
# Out:
#    order_id customer_id country           product category  price  quantity  \
# 0         1        C001      SG  Ink Tank Printer  Printer  299.0       1.0
#
#          order_date            email
# 0  2025-01-01 10:05  USER1@EMAIL.COM

# %% [markdown]
# #### manual way

# %%
df[df["country"] == "SG"]
# Out:
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
#
#    quantity        order_date            email
# 0       1.0  2025-01-01 10:05  USER1@EMAIL.COM
# 2       3.0  2025-01-02 09:30  user1@email.com
# 4       NaN  2025-01-03 16:45  user4@email.com

# %%
df[df["price"] >= 200]
# Out:
#    order_id customer_id country           product category  price  quantity  \
# 0         1        C001      SG  Ink Tank Printer  Printer  299.0       1.0
# 6         7        C005      PH  Ink Tank Printer  Printer  289.0       1.0
#
#          order_date            email
# 0  2025-01-01 10:05  USER1@EMAIL.COM
# 6  2025-01-04 10:00  user5@email.com

# %%
df_price_200=\
(
    df[df["price"] >= 200]
)

# %%
df_sg_printers=\
(
    df[
    (df["country"] == "SG") &
    (df["category"] == "Printer")]
)
df_sg_printers
# Out:
#    order_id customer_id country           product category  price  quantity  \
# 0         1        C001      SG  Ink Tank Printer  Printer  299.0       1.0
#
#          order_date            email
# 0  2025-01-01 10:05  USER1@EMAIL.COM

# %% [markdown]
# #### Filtering row/s with NaN

# %%
df_quantity_missing=\
(
    df[df["quantity"].isna()]
)

df_quantity_missing
# Out:
#    order_id customer_id country product    category  price  quantity  \
# 4         5        C004      SG   Toner  Consumable  120.0       NaN
#
#          order_date            email
# 4  2025-01-03 16:45  user4@email.com

# %%
df_price_missing=\
(
    df[df["price"].isna()]
)

df_price_missing
# Out:
#    order_id customer_id country       product category  price  quantity  \
# 3         4        C003      TH  Colour Laser  Printer    NaN       1.0
#
#          order_date            email
# 3  2025-01-02 14:00  user3@email.com

# %%
#### preview dataframe to compare output
df
# Out:
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 3         4        C003      TH      Colour Laser     Printer    NaN
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity        order_date            email
# 0       1.0  2025-01-01 10:05  USER1@EMAIL.COM
# 1       2.0  2025-01-01 11:10  user2@email.com
# 2       3.0  2025-01-02 09:30  user1@email.com
# 3       1.0  2025-01-02 14:00  user3@email.com
# 4       NaN  2025-01-03 16:45  user4@email.com
# 5       5.0  2025-01-03 17:10  user2@email.com
# 6       1.0  2025-01-04 10:00  user5@email.com

# %% [markdown]
# #### Remove rows with NaN using .dropna

# %%
df_clean=\
(
    df
    .dropna(subset = ["price"])
)

df_clean
# Out:
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity        order_date            email
# 0       1.0  2025-01-01 10:05  USER1@EMAIL.COM
# 1       2.0  2025-01-01 11:10  user2@email.com
# 2       3.0  2025-01-02 09:30  user1@email.com
# 4       NaN  2025-01-03 16:45  user4@email.com
# 5       5.0  2025-01-03 17:10  user2@email.com
# 6       1.0  2025-01-04 10:00  user5@email.com

# %% [markdown]
# #### Fill NaN with any values you want. Both numbers and strings are acceptable

# %%
df_clean["quantity"]=\
(
    df_clean["quantity"].fillna(1)
)

df_clean
# Out:
# /var/folders/_2/_sjty54d39lfdb9g4lc7wnbh0000gn/T/ipykernel_67493/3398673974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["quantity"]=\
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity        order_date            email
# 0       1.0  2025-01-01 10:05  USER1@EMAIL.COM
# 1       2.0  2025-01-01 11:10  user2@email.com
# 2       3.0  2025-01-02 09:30  user1@email.com
# 4       1.0  2025-01-03 16:45  user4@email.com
# 5       5.0  2025-01-03 17:10  user2@email.com
# 6       1.0  2025-01-04 10:00  user5@email.com

# %% [markdown]
# #### Resetting index after removing rows

# %%
(
    df_clean
    .reset_index()
)
# Out:
#    index  order_id customer_id country           product    category  price  \
# 0      0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1      1         2        C002      MY        Mono Laser     Printer  199.0
# 2      2         3        C001      SG        Ink Bottle  Consumable   15.0
# 3      4         5        C004      SG             Toner  Consumable  120.0
# 4      5         6        C002      MY        Ink Bottle  Consumable   15.0
# 5      6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity        order_date            email
# 0       1.0  2025-01-01 10:05  USER1@EMAIL.COM
# 1       2.0  2025-01-01 11:10  user2@email.com
# 2       3.0  2025-01-02 09:30  user1@email.com
# 3       1.0  2025-01-03 16:45  user4@email.com
# 4       5.0  2025-01-03 17:10  user2@email.com
# 5       1.0  2025-01-04 10:00  user5@email.com

# %% [markdown]
# #### Changing data type to integer

# %%
df_clean["quantity"]=\
(
    df_clean["quantity"].astype(int)
)
# Out:
# /var/folders/_2/_sjty54d39lfdb9g4lc7wnbh0000gn/T/ipykernel_67493/2642054179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["quantity"]=\

# %% [markdown]
# #### Changing data type to datetime

# %%
df_clean["order_date"]=\
(
    pd.to_datetime(df_clean["order_date"])
)
# Out:
# /var/folders/_2/_sjty54d39lfdb9g4lc7wnbh0000gn/T/ipykernel_67493/814792843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["order_date"]=\

# %%
#### Preview data after changing data type
df_clean
# Out:
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity          order_date            email
# 0         1 2025-01-01 10:05:00  USER1@EMAIL.COM
# 1         2 2025-01-01 11:10:00  user2@email.com
# 2         3 2025-01-02 09:30:00  user1@email.com
# 4         1 2025-01-03 16:45:00  user4@email.com
# 5         5 2025-01-03 17:10:00  user2@email.com
# 6         1 2025-01-04 10:00:00  user5@email.com

# %%
#### Sanity check to ensure data type is changed accurately
(
    df_clean.dtypes
)
# Out:
# order_id                int64
# customer_id            object
# country                object
# product                object
# category               object
# price                 float64
# quantity                int64
# order_date     datetime64[ns]
# email                  object
# dtype: object

# %% [markdown]
# ### Add Hour, Days Column after unlocking datetime format

# %%
df_clean["order_hour"]=\
(
    df_clean["order_date"].dt.hour
)

df_clean
# Out:
# /var/folders/_2/_sjty54d39lfdb9g4lc7wnbh0000gn/T/ipykernel_67493/1190713754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["order_hour"]=\
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity          order_date            email  order_hour
# 0         1 2025-01-01 10:05:00  USER1@EMAIL.COM          10
# 1         2 2025-01-01 11:10:00  user2@email.com          11
# 2         3 2025-01-02 09:30:00  user1@email.com           9
# 4         1 2025-01-03 16:45:00  user4@email.com          16
# 5         5 2025-01-03 17:10:00  user2@email.com          17
# 6         1 2025-01-04 10:00:00  user5@email.com          10

# %%
df_clean["order_day"]=\
(
    df_clean["order_date"].dt.day_name()
)

df_clean
# Out:
# /var/folders/_2/_sjty54d39lfdb9g4lc7wnbh0000gn/T/ipykernel_67493/3362579504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["order_day"]=\
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity          order_date            email  order_hour  order_day
# 0         1 2025-01-01 10:05:00  USER1@EMAIL.COM          10  Wednesday
# 1         2 2025-01-01 11:10:00  user2@email.com          11  Wednesday
# 2         3 2025-01-02 09:30:00  user1@email.com           9   Thursday
# 4         1 2025-01-03 16:45:00  user4@email.com          16     Friday
# 5         5 2025-01-03 17:10:00  user2@email.com          17     Friday
# 6         1 2025-01-04 10:00:00  user5@email.com          10   Saturday

# %% [markdown]
# ### Creating a new column with feature engineering

# %%
df_clean["revenue"]=\
(
    df_clean["price"] * df_clean["quantity"]
)

df_clean
# Out:
# /var/folders/_2/_sjty54d39lfdb9g4lc7wnbh0000gn/T/ipykernel_67493/896292388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["revenue"]=\
#    order_id customer_id country           product    category  price  \
# 0         1        C001      SG  Ink Tank Printer     Printer  299.0
# 1         2        C002      MY        Mono Laser     Printer  199.0
# 2         3        C001      SG        Ink Bottle  Consumable   15.0
# 4         5        C004      SG             Toner  Consumable  120.0
# 5         6        C002      MY        Ink Bottle  Consumable   15.0
# 6         7        C005      PH  Ink Tank Printer     Printer  289.0
#
#    quantity          order_date            email  order_hour  order_day  \
# 0         1 2025-01-01 10:05:00  USER1@EMAIL.COM          10  Wednesday
# 1         2 2025-01-01 11:10:00  user2@email.com          11  Wednesday
# 2         3 2025-01-02 09:30:00  user1@email.com           9   Thursday
# 4         1 2025-01-03 16:45:00  user4@email.com          16     Friday
# 5         5 2025-01-03 17:10:00  user2@email.com          17     Friday
# 6         1 2025-01-04 10:00:00  user5@email.com          10   Saturday
#
#    revenue
# 0    299.0
# 1    398.0
# 2     45.0
# 4    120.0
# 5     75.0
# 6    289.0
